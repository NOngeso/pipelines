# %%
import pandas as pd
from intermine.webservice import Service
service = Service("https://phytozome.jgi.doe.gov/phytomine/service")

def get_cds(name): # name should be transcript name
    template = service.get_template('Transcript_CDS_sequence')
    rows = template.rows(
        A = {"op": "=", "value": name}
        )
    for row in rows:
        return row["CDSs.sequence.residues"]

def get_pep(name): # name should be transcript name
    template = service.get_template('Transcript_peptide_sequence')
    rows = template.rows(
        A = {"op": "=", "value": name}
        )
    for row in rows:
        return row["sequence.residues"]

# %%
def get_info_phyto(genelist): # genelist should be consisted with genenames
    service = Service("https://phytozome.jgi.doe.gov/phytomine/service")
    dic = {"organism.shortName" : [],
           "primaryIdentifier" : [],
           "briefDescription" : [],
           "symbol" : [],
           "description" : [],
           "Name" : []
           }
    # The view specifies the output columns
    for gene in genelist:
        query = service.new_query("Gene")
        query.add_view(
        "primaryIdentifier", "briefDescription", "symbol",
        "description", "organism.shortName","name"
        )
        query.add_constraint("primaryIdentifier", "=", gene, code = "A")
        for row in query.rows():
            dic["organism.shortName"].append(row["organism.shortName"])
            dic["primaryIdentifier"].append(row["primaryIdentifier"])
            dic["briefDescription"].append(row["briefDescription"])
            dic["symbol"].append(row["symbol"])
            dic["description"].append(row["description"])
            dic["Name"].append(row["name"])
                
    return dic

# %%
def get_info_thale(genelist): # genelist should be consisted with genenames
    service = Service("https://apps.araport.org/thalemine/service")
    dic = {"organism.shortName" : [],
           "primaryIdentifier" : [],
           "briefDescription" : [],
           "symbol" : [],
           "description" : [],
           "Name" : []
           }
    # The view specifies the output columns
    for gene in genelist:
        query = service.new_query("Gene")
        query.add_view(
        "primaryIdentifier", "briefDescription", "symbol",
        "description", "organism.shortName","name"
        )
        query.add_constraint("primaryIdentifier", "=", gene, code = "A")
        for row in query.rows():
            dic["organism.shortName"].append(row["organism.shortName"])
            dic["primaryIdentifier"].append(row["primaryIdentifier"])
            dic["briefDescription"].append(row["briefDescription"])
            dic["symbol"].append(row["symbol"])
            dic["description"].append(row["description"])
            dic["Name"].append(row["name"])
                
    return dic

# %%
# Get a new query on the class (table) you will be querying:
def gene2homologs(genename,organism1,organism2):
    service = Service("https://phytozome.jgi.doe.gov/phytomine/service")
    query = service.new_query("Homolog")
    # The view specifies the output columns
    query.add_view(
        "gene1.primaryIdentifier", "gene2.primaryIdentifier", "organism2.shortName",
        "relationship"
    )
    # Uncomment and edit the line below (the default) to select a custom sort order:
    # query.add_sort_order("Homolog.gene1.primaryIdentifier", "ASC")
    # You can edit the constraint values below
    query.add_constraint("gene1.primaryIdentifier", "=", genename, code = "A")
    query.add_constraint("organism1.shortName", "=", organism1, code = "B")
    query.add_constraint("organism2.shortName", "=", organism2, code = "C")
    # Uncomment and edit the code below to specify your own custom logic:
    #query.set_logic("A and B and (C or D or E or F)")
    homolog = []
    for row in query.rows():
        homolog.append(row["gene2.primaryIdentifier"])
    return list(set(homolog))

# %%
def getClusterID(genename,organism):
    service = Service("https://phytozome.jgi.doe.gov/phytomine/service")
    # Get a new query on the class (table) you will be querying:
    query = service.new_query("ProteinFamily")
    # The view specifies the output columns
    query.add_view(
        "clusterId", "gene.primaryIdentifier", "gene.briefDescription",
        "gene.organism.shortName", "gene.symbol"
    )
    # Uncomment and edit the line below (the default) to select a custom sort order:
    # query.add_sort_order("ProteinFamily.clusterId", "ASC")
    # You can edit the constraint values below
    query.add_constraint("gene.primaryIdentifier", "=", genename, code = "A")
    query.add_constraint("gene.organism.shortName", "=", organism, code = "B")
    # Uncomment and edit the code below to specify your own custom logic:
    #query.set_logic("A" and "B")
    clusterID = []
    for row in query.rows():
        #print row["clusterId"], row["gene.primaryIdentifier"], row["gene.briefDescription"], \
        #    row["gene.organism.shortName"], row["gene.symbol"]
        clusterID.append(row["clusterId"])
    return(clusterID)

# %%
def get_genelistfromClusterID(clusteridlist,organism):
    service = Service("https://phytozome.jgi.doe.gov/phytomine/service")
    # Get a new query on the class (table) you will be querying:
    genelist = []
    for clusterid in clusteridlist:
        query = service.new_query("ProteinFamily")
        # The view specifies the output columns
        query.add_view(
            "clusterId", "gene.primaryIdentifier", "gene.briefDescription",
            "gene.organism.shortName", "gene.symbol"
        )
        # Uncomment and edit the line below (the default) to select a custom sort order:
        # query.add_sort_order("ProteinFamily.clusterId", "ASC")
        # You can edit the constraint values below
        query.add_constraint("clusterId", "=", clusterid, code = "A")
        query.add_constraint("gene.organism.shortName", "=", organism, code = "B")
        # Uncomment and edit the code below to specify your own custom logic:
        # query.set_logic("A")
        
        for row in query.rows():
            #print row["clusterId"], row["gene.primaryIdentifier"], row["gene.briefDescription"], \
            #    row["gene.organism.shortName"], row["gene.symbol"]
            genelist.append(row["gene.primaryIdentifier"])
    return(set(genelist))

# %%
def gene2genefamiliy(genename,organism):
    genelist = get_genelistfromClusterID(getClusterID(genename,organism),organism)
    return(list(genelist))

# %%
getClusterID('AT5G21960','A. thaliana')
# Out:
# [27860306,
#  63455334,
#  63601196,
#  63847027,
#  64102876,
#  64211139,
#  64529071,
#  64602490,
#  64927177,
#  65167215,
#  65392492]

# %%
get_genelistfromClusterID([63601196],'A. thaliana')
# Out:
# {u'AT1G19210',
#  u'AT1G21910',
#  u'AT1G44830',
#  u'AT1G74930',
#  u'AT1G77640',
#  u'AT5G21960'}

# %%
gene2genefamiliy('AT5G21960','A. thaliana')
# Out:
# [u'AT1G44830',
#  u'AT1G77640',
#  u'AT1G74930',
#  u'AT5G21960',
#  u'AT1G19210',
#  u'AT1G21910']

# %%
get_info_phyto(['AT1G01360'])
# Out:
# {'Name': [u'AT1G01360'],
#  'briefDescription': [u'regulatory component of ABA receptor 1'],
#  'description': [None],
#  'organism.shortName': [u'A. thaliana'],
#  'primaryIdentifier': [u'AT1G01360'],
#  'symbol': [None]}

# %%
dic = get_info_phyto(Primary_DroughtDB)
# Out:
# ---------------------------------------------------------------------------
# WebserviceError                           Traceback (most recent call last)
# <ipython-input-16-45eb4b721333> in <module>()
# ----> 1 dic = get_info_phyto(Primary_DroughtDB)
#
# <ipython-input-2-0f48ed141457> in get_info_phyto(genelist)
#      16         )
#      17         query.add_constraint("primaryIdentifier", "=", gene, code = "A")
# ---> 18         for row in query.rows():
#      19             dic["organism.shortName"].append(row["organism.shortName"])
#      20             dic["primaryIdentifier"].append(row["primaryIdentifier"])
#
# /usr/local/lib/python2.7/dist-packages/intermine-1.9.5-py2.7.egg/intermine/results.pyc in __iter__(self)
#     385         Returns the internal iterator object.
#     386         """
# --> 387         con = self.opener.open(self.url, self.data)
#     388         identity = lambda x: x
#     389         flat_file_parser = lambda: FlatFileIterator(con, identity)
#
# /usr/local/lib/python2.7/dist-packages/intermine-1.9.5-py2.7.egg/intermine/results.pyc in open(self, url, data, headers, method)
#     651                     500: self.http_error_500
#     652                     }.get(e.code, self.http_error_default)
# --> 653             handler(*args)
#     654
#     655     def read(self, url, data = None):
#
# /usr/local/lib/python2.7/dist-packages/intermine-1.9.5-py2.7.egg/intermine/results.pyc in http_error_default(self, url, fp, errcode, errmsg, headers)
#     678         content = fp.read()
#     679         fp.close()
# --> 680         raise WebserviceError(errcode, errmsg, content)
#     681
#     682     def http_error_400(self, url, fp, errcode, errmsg, headers, data=None):
#
# WebserviceError: [Errno 502] Proxy Error: '<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">\n<html><head>\n<title>502 Proxy Error</title>\n</head><body>\n<h1>Proxy Error</h1>\n<p>The proxy server received an invalid\r\nresponse from an upstream server.<br />\r\nThe proxy server could not handle the request <em><a href="/phytomine/service/query/results">POST&nbsp;/phytomine/service/query/results</a></em>.<p>\nReason: <strong>Error reading from remote server</strong></p></p>\n</body></html>\n'

# %%
df = pd.DataFrame(dic)
df
# Out:
#                                       briefDescription description  \
# 0               regulatory component of ABA receptor 1        None
# 1                               ascorbate peroxidase 1        None
# 2                                myb domain protein 60        None
# 3                                myb domain protein 61        None
# 4        dsRNA-binding domain-like superfamily protein        None
# 5             Glutathione S-transferase family protein        None
# 6    Undecaprenyl pyrophosphate synthetase family p...        None
# 7    C4-dicarboxylate transporter/malic acid transp...        None
# 8       Integrase-type DNA-binding superfamily protein        None
# 9                       pleiotropic drug resistance 12        None
# 10          Inorganic H pyrophosphatase family protein        None
# 11   light harvesting complex photosystem II subunit 6        None
# 12          ARIA-interacting double AP2 domain protein        None
# 13         molybdenum cofactor sulfurase (LOS5) (ABA3)        None
# 14                          salt tolerance zinc finger        None
# 15                               syntaxin of plants 61        None
# 16   Basic helix-loop-helix (bHLH) DNA-binding fami...        None
# 17   Disease resistance protein (CC-NBS-LRR class) ...        None
# 18                                           annexin 1        None
# 19   abscisic acid responsive elements-binding fact...        None
# 20                        G-protein-coupled receptor 1        None
# 21   Stabilizer of iron transporter SufD / Polynucl...        None
# 22                      RING/U-box superfamily protein        None
# 23                                 beta glucosidase 18        None
# 24                        nuclear factor Y, subunit A5        None
# 25                               galactinol synthase 2        None
# 26    FAD/NAD(P)-binding oxidoreductase family protein        None
# 27                 respiratory burst oxidase protein F        None
# 28                               GPCR-type G protein 1        None
# 29                      receptor-like protein kinase 1        None
# ..                                                 ...         ...
# 115           AP2 domain containing protein, expressed        None
# 116    inhibitor I family protein, putative, expressed        None
# 117  MYB family transcription factor, putative, exp...        None
# 118  CAMK_KIN1/SNF1/Nim1_like.11 - CAMK includes ca...        None
# 119           AP2 domain containing protein, expressed        None
# 120  MYB family transcription factor, putative, exp...        None
# 121  OsCML31 - Calmodulin-related calcium sensor pr...        None
# 122                          WAX2, putative, expressed        None
# 123           AP2 domain containing protein, expressed        None
# 124             aquaporin protein, putative, expressed        None
# 125             aquaporin protein, putative, expressed        None
# 126     bZIP transcription factor, putative, expressed        None
# 127             aquaporin protein, putative, expressed        None
# 128        fatty acid hydroxylase, putative, expressed        None
# 129  CAMK_CAMK_like.17 - CAMK includes calcium/calm...        None
# 130  NAC domain-containing protein 67, putative, ex...        None
# 131  protein kinase domain containing protein, expr...        None
# 132                                  WRKY45, expressed        None
# 133               purine permease, putative, expressed        None
# 134  NAD dependent epimerase/dehydratase family pro...        None
# 135  zinc finger A20 and AN1 domain-containing stre...        None
# 136  zinc finger A20 and AN1 domain-containing stre...        None
# 137           spermidine synthase, putative, expressed        None
# 138  CAMK_KIN1/SNF1/Nim1_like.32 - CAMK includes ca...        None
# 139           AP2 domain containing protein, expressed        None
# 140  tyrosine phosphatase family protein, putative,...        None
# 141  CPuORF2 - conserved peptide uORF-containing tr...        None
# 142     bZIP transcription factor, putative, expressed        None
# 143  dehydration-responsive element-binding protein...        None
# 144  CAMK_KIN1/SNF1/Nim1_like.4 - CAMK includes cal...        None
#
#     organism.shortName primaryIdentifier symbol
# 0          A. thaliana         AT1G01360   None
# 1          A. thaliana         AT1G07890   None
# 2          A. thaliana         AT1G08810   None
# 3          A. thaliana         AT1G09540   None
# 4          A. thaliana         AT1G09700   None
# 5          A. thaliana         AT1G10370   None
# 6          A. thaliana         AT1G11755   None
# 7          A. thaliana         AT1G12480   None
# 8          A. thaliana         AT1G15360   None
# 9          A. thaliana         AT1G15520   None
# 10         A. thaliana         AT1G15690   None
# 11         A. thaliana         AT1G15820   None
# 12         A. thaliana         AT1G16060   None
# 13         A. thaliana         AT1G16540   None
# 14         A. thaliana         AT1G27730   None
# 15         A. thaliana         AT1G28490   None
# 16         A. thaliana         AT1G32640   None
# 17         A. thaliana         AT1G33560   None
# 18         A. thaliana         AT1G35720   None
# 19         A. thaliana         AT1G45249   None
# 20         A. thaliana         AT1G48270   None
# 21         A. thaliana         AT1G48410   None
# 22         A. thaliana         AT1G49230   None
# 23         A. thaliana         AT1G52400   None
# 24         A. thaliana         AT1G54160   None
# 25         A. thaliana         AT1G56600   None
# 26         A. thaliana         AT1G58440   None
# 27         A. thaliana         AT1G64060   None
# 28         A. thaliana         AT1G64990   None
# 29         A. thaliana         AT1G69270   None
# ..                 ...               ...    ...
# 115          O. sativa    LOC_Os01g07120   None
# 116          O. sativa    LOC_Os01g42860   None
# 117          O. sativa    LOC_Os01g50110   None
# 118          O. sativa    LOC_Os01g55450   None
# 119          O. sativa    LOC_Os01g58420   None
# 120          O. sativa    LOC_Os01g62410   None
# 121          O. sativa    LOC_Os01g72530   None
# 122          O. sativa    LOC_Os02g08230   None
# 123          O. sativa    LOC_Os02g10760   None
# 124          O. sativa    LOC_Os02g41860   None
# 125          O. sativa    LOC_Os02g44630   None
# 126          O. sativa    LOC_Os02g52780   None
# 127          O. sativa    LOC_Os02g57720   None
# 128          O. sativa    LOC_Os03g03370   None
# 129          O. sativa    LOC_Os03g03660   None
# 130          O. sativa    LOC_Os03g60080   None
# 131          O. sativa    LOC_Os04g56130   None
# 132          O. sativa    LOC_Os05g25770   None
# 133          O. sativa    LOC_Os05g48300   None
# 134          O. sativa    LOC_Os05g51670   None
# 135          O. sativa    LOC_Os06g41010   None
# 136          O. sativa    LOC_Os07g07350   None
# 137          O. sativa    LOC_Os07g22600   None
# 138          O. sativa    LOC_Os07g48760   None
# 139          O. sativa    LOC_Os08g35240   None
# 140          O. sativa    LOC_Os09g05020   None
# 141          O. sativa    LOC_Os09g13570   None
# 142          O. sativa    LOC_Os09g28310   None
# 143          O. sativa    LOC_Os09g35030   None
# 144          O. sativa    LOC_Os11g02240   None
#
# [145 rows x 5 columns]

# %%
dic = {'DroughtDB':[],
       'A. thaliana':[],
       'A. halleri early-release':[],
       'A. lyrata':[],
       'E. salsugineum':[]
       }
for i in df.index:
    genename = df.loc[i]['primaryIdentifier']
    organism1 = df.loc[i]['organism.shortName']
    target_organisms = ['A. thaliana','A. halleri early-release','A. lyrata','E. salsugineum']
    orthgenes = []
    dic['DroughtDB'].append(genename)
    for organism2 in target_organisms:
        if organism2 == organism1:
            #orthgenes.append(genename)
            #dic[organism2].append(genename)
            dic[organism2].append([genename] + gene2genefamiliy(genename,organism1))
        else:
            #orthgenes.append(gene2homologs(genename,organism1,organism2))
            outgene = gene2homologs(genename,organism1,organism2)
            if outgene != []:
                homo_outgene = gene2genefamiliy(outgene[0],organism2)
            else: homo_outgene = []
            dic[organism2].append(list(set(outgene+homo_outgene)))
        #dic[organism2].append(gene2homologs(genename,organism1,organism2))
    #print genename, orthgenes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c6b779ab3d8c> in <module>()
#       5        'E. salsugineum':[]
#       6        }
# ----> 7 for i in df.index:
#       8     genename = df.loc[i]['primaryIdentifier']
#       9     organism1 = df.loc[i]['organism.shortName']
#
# NameError: name 'df' is not defined

# %%
len(dic['A. halleri early-release'])
# Out:
# 145

# %%
df_homo = pd.DataFrame(dic,columns=['DroughtDB','A. thaliana','A. lyrata','A. halleri early-release','E. salsugineum'])
df_homo.to_csv('DroughtNet.Primary.Orth.Homo.ver2.txt',sep='\t')

# %%
# 94       [Araha.17172s0001]  [Thhalv10020591m.g, Thhalv10016581m.g, Thhalv1...
# 95       [Araha.18038s0004]  [Thhalv10012617m.g, Thhalv10006930m.g, Thhalv1...
# 96        [Araha.4128s0001]                                [Thhalv10005202m.g]
# 97       [Araha.35413s0002]  [Thhalv10003679m.g, Thhalv10003643m.g, Thhalv1...
# 98        [Araha.7329s0001]  [Thhalv10012591m.g, Thhalv10010143m.g, Thhalv1...
# 99       [Araha.16901s0006]  [Thhalv10017537m.g, Thhalv10006200m.g, Thhalv1...
#
# [100 rows x 5 columns]

# %%
# Successfully orthologous DroughtDB genes
len(df_homo['DroughtDB'])
# Out:
# 145

# %%
# genefamilies in Ath
x = []
for y in df_homo['A. thaliana']:
    x += y
len(set(x))
# Out:
# 739

# %%
# genefamilies in Aly
x = []
for y in df_homo['A. lyrata']:
    x += y
len(set(x))
# Out:
# 696

# %%
# genefamilies in Aha
x = []
for y in df_homo['A. halleri early-release']:
    x += y
len(set(x))
# Out:
# 120

# %%
# genefamilies in Esa
x = []
for y in df_homo['E. salsugineum']:
    x += y
len(set(x))
# Out:
# 781

# %%
dic = {'DroughtDB':[],
       'A.thaliana':[]
        }
for i in df_homo.index:
    ath_list = df_homo.loc[i]['A. thaliana']
    DDB_genename = df_homo.loc[i]['DroughtDB']
    dic['A.thaliana'] += ath_list
    dic['DroughtDB'] += [DDB_genename] * len(ath_list)

# %%
len(pd.DataFrame(dic)['A.thaliana'])
# Out:
# 1129

# %%
dic2 = get_info_thale(dic['A.thaliana'])

# %%
dic.update(dic2)

# %%
df_homo_ath = pd.DataFrame(dic)
df_homo_ath.to_csv('DroughtNet.Primary.Orth.Homo.ATH.ver2.txt',sep='\t')

# %%
len(df_homo_ath)
# Out:
# 1129

# %%
get_info_thale(['AT4G36920'])
# Out:
# {'Name': [u'APETALA 2'],
#  'briefDescription': [u'Integrase-type DNA-binding superfamily protein'],
#  'description': [None],
#  'organism.shortName': [u'A. thaliana'],
#  'primaryIdentifier': [u'AT4G36920'],
#  'symbol': [u'AP2']}

# %%
genelist_temp = []
for each in df_homo['A. lyrata']:
    genelist_temp += each
print len(genelist_temp)
print len(set(genelist_temp))
# Out:
# 756
# 623

# %%
pd.DataFrame(get_info(df_homo['A. thaliana'][10]))
# Out:
#                              briefDescription description organism.shortName  \
# 0  Inorganic H pyrophosphatase family protein        None        A. thaliana
#
#   primaryIdentifier symbol
# 0         AT1G15690   None

# %%
gene2homologs('AT1G01360','A. thaliana','A. thaliana')
# Out:
# [u'AT4G01026',
#  u'AT5G53160',
#  u'AT5G05440',
#  u'AT2G40330',
#  u'AT2G38310',
#  u'AT4G27920']

# %%
# 길어서 밑으로 내려놓음 ! 
Primary_DroughtDB = '''AEGTA00197
AEGTA05384
AEGTA07634
AEGTA28497
AEGTA28957
AT1G01360
AT1G07890
AT1G08810
AT1G09540
AT1G09700
AT1G10370
AT1G11755
AT1G12480
AT1G15360
