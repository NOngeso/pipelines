# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#colors = sns.color_palette("deep", 20)
colors = sns.choose_colorbrewer_palette('qualitative') #{‘sequential’, ‘diverging’, ‘qualitative’}
sns.set(context="poster")
sns.set_style("dark")

# %%
file_in = 'D:/analysis/Creinhardtii/samples.txt'
bulk = open(file_in).read()
bulk = bulk.split('\n')
x_i = [x.split()[0] for x in bulk if x.strip() != '']
y_i = [x.split()[1] for x in bulk if x.strip() != '']
plt.scatter(x_i, y_i, alpha=0.5)
