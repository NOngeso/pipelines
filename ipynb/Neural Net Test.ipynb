# %%
# %matplotlib inline
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
X, a = datasets.make_moons(200, noise=0.20)
plt.scatter(X[:,0], X[:,1], s=40, c=y, cmap=plt.cm.Spectral)

# %%
X[0:10]
# Out:
# array([[ 0.74346118,  0.46465633],
#        [ 1.65755662, -0.63203157],
#        [-0.15878875,  0.25584465],
#        [-1.088752  , -0.39694315],
#        [ 1.768052  , -0.25443213],
#        [ 1.95416454, -0.12850579],
#        [ 0.93694537,  0.36597075],
#        [ 0.88446589, -0.47595401],
#        [ 0.80950246,  0.3505231 ],
#        [ 1.2278091 , -0.64785108]])

# %%
a[0:10]
# Out:
# array([0, 1, 1, 0, 1, 1, 0, 1, 0, 1], dtype=int64)

# %%
# sensor independent

reaction = [0,1]
#sensor_x
#sensor_y 
happy_x  = {}
stress_x = {}
happy_y = {}
stress_y = {}
for i, (x,y) in enumerate(X):
    for c in reaction: 
        if c == a[i]:
            o = c
            try:
                happy_x[(x,o)] += 1
            except KeyError:
                happy_x[(x,o)] = 1
            try:
                happy_y[(y,o)] += 1
            except KeyError:
                happy_y[(y,o)] = 1
            
        else:
            o = c
            try:
                stress_x[(x,o)] += 1
            except KeyError:
                stress_x[(x,o)] = 1
            try:
                stress_y[(y,o)] += 1
            except KeyError:
                stress_y[(y,o)] = 1

print stress_x
# Out:
# {(0.75877113655524075, 1): 1, (0.10235329905508572, 1): 1, (1.164433013996391, 1): 1, (-0.33698824618194984, 1): 1, (1.6575566177861694, 0): 1, (-0.003532337476121826, 0): 1, (0.84248306648189519, 1): 1, (0.93694536930213645, 1): 1, (0.11834786252473045, 1): 1, (0.30966002558255268, 1): 1, (-0.93516751690410072, 1): 1, (0.82262609481518423, 1): 1, (-0.52953439108442546, 0): 1, (1.9931767595778087, 0): 1, (0.092521345685207756, 0): 1, (1.9267301885914556, 0): 1, (1.1234462460084944, 1): 1, (0.69752160001386054, 1): 1, (1.0193480669297958, 0): 1, (0.48281720635842351, 0): 1, (0.18911690841579221, 1): 1, (0.8496547032981957, 0): 1, (-1.3210980458207677, 1): 1, (0.10599360007626221, 1): 1, (0.88357042556658394, 0): 1, (-0.25253386990926946, 0): 1, (-1.0787343521460877, 1): 1, (1.7734639983958691, 0): 1, (-0.97644616707217213, 1): 1, (1.3273443236560003, 0): 1, (1.6017216453007181, 0): 1, (1.025923246781322, 1): 1, (1.3044087705439906, 0): 1, (1.7737739717159346, 0): 1, (-0.72894227614909
# ...
