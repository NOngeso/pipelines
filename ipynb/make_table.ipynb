# %%
import pandas as pd
import numpy as np
basedir = 'D:/analysis/Creinhardtii/'
file_cds = basedir + 'primers.sts.cds.out'
file_gene = basedir + 'primers.sts.gene.out'
file_assem = basedir + 'primers.sts.cdhit.out'
df = pd.DataFrame(columns=('genename','offtarget','# match within CDS','CDS','Gene','RNAseq'))
df_out = pd.DataFrame(columns=('genename','targets'))
df_cds = pd.read_csv(file_cds,sep='\t',skiprows=1,header=None)
df_gene = pd.read_csv(file_gene,sep='\t',skiprows=1,header=None)
df_assem = pd.read_csv(file_assem,sep='\t',skiprows=1,header=None)

# %%
i = 0 

dic = {}
for j in df_cds.index.values:
    #print j
    if df_cds.loc[j][0] == '#- Done' or df_cds.loc[j][0] == '#- sts':
        continue
    gn  = df_cds.loc[j][0]
    tgn = '.'.join(df_cds.loc[j][1].split('.')[0:2])
    left = df_cds.loc[j][3]
    leng = df_cds.loc[j][7].split('/')[0]
    if gn == tgn and left == '1':
        try:
            ix = dic[gn]
            df.loc[(ix,'# match')] += 1
            df.loc[ix][3].append(leng)
        except KeyError:
            df.loc[i] = [gn,0,1,[leng],[],[]]
            dic[gn] = i
            i += 1
            
i_out = 0    
dic_out = {}
for j in df_cds.index.values:
    #print j
    if df_cds.loc[j][0] == '#- Done' or df_cds.loc[j][0] == '#- sts':
        continue
    gn  = df_cds.loc[j][0]
    tgn = '.'.join(df_cds.loc[j][1].split('.')[0:2])
    left = df_cds.loc[j][3]
    leng = df_cds.loc[j][7].split('/')[0]
    
    if gn != tgn:
        try:
            ix_out = dic_out[gn]
            df_out.loc[(ix_out,'targets')].append(tgn)
            
        except KeyError:
            df_out.loc[i_out] = [gn,[tgn]]
            dic_out[gn] = i_out
            i_out += 1
        try:
            ix = dic[gn]
            df.loc[(ix,'offtarget')] = 1
        except KeyError:
            print '!' 
            exit()

            

for j in df_gene.index.values:
    #print j
    if df_gene.loc[j][0] == '#- Done' or df_gene.loc[j][0] == '#- sts':
        continue
    gn  = df_gene.loc[j][0]
    tgn = '.'.join(df_gene.loc[j][1].split('.')[0:2])
    left = df_gene.loc[j][3]
    leng = df_gene.loc[j][7].split('/')[0]
    if gn == tgn:
        try:
            ix = dic[gn]
            #df.loc[ix][1] += 1
            df.loc[ix][4].append(leng)
        except KeyError:
            print '!'
            exit()
            #df.loc[i] = [gn,1,leng,0,0]
            #dic[gn] = i
            #i += 1
for j in df_assem.index.values:
    #print j
    if df_assem.loc[j][0] == '#- Done' or df_assem.loc[j][0] == '#- sts':
        continue
    gn  = df_assem.loc[j][0]
    tgn = '.'.join(df_assem.loc[j][1].split('.')[0:2])
    left = df_assem.loc[j][3]
    leng = df_assem.loc[j][7].split('/')[0]
    if 1:
        try:
            ix = dic[gn]
            #df.loc[ix][1] += 1
            df.loc[ix][5].append(leng)
        except KeyError:
            print '!'
            pass
            #exit()
            #df.loc[i] = [gn,1,leng,0,0]
            #dic[gn] = i
            #i += 1

# %%
df_mayra = pd.read_csv(basedir+'mayra_pcr_ver2.txt',sep='\t')
df_mayra_i = df_mayra.set_index('ChlreGene_ID55')

# %%
df_mayra_i.head()
# Out:
#                         Chlre4_ID  right size  band - wrong size  no band  \
# ChlreGene_ID55
# Cre11.g468300    jgi|Chlre4|82091           1                NaN      NaN
# Cre06.g260400   jgi|Chlre4|187189           1                NaN      NaN
# Cre01.g025025   jgi|Chlre4|189825           0                NaN        1
# Cre02.g077500    jgi|Chlre4|53681           1                NaN      NaN
# Cre07.g330950   jgi|Chlre4|195457           0                NaN        1
#
#                 platename  Pos.Nr Position  ORF_Size5  right size.1  \
# ChlreGene_ID55
# Cre11.g468300   P1kCre1+2       1       A1        579             1
# Cre06.g260400   P1kCre1+2       2       B1        369             1
# Cre01.g025025   P1kCre1+2       3       C1        393             0
# Cre02.g077500   P1kCre1+2       4       D1        417             1
# Cre07.g330950   P1kCre1+2       5       E1        435             0
#
#                 band - wrong size.1  no band.1  \
# ChlreGene_ID55
# Cre11.g468300                   NaN        NaN
# Cre06.g260400                   NaN        NaN
# Cre01.g025025                   NaN          1
# Cre02.g077500                   NaN        NaN
# Cre07.g330950                   NaN          1
#
#                 other band - wrong size, too big  \
# ChlreGene_ID55
# Cre11.g468300                                NaN
# Cre06.g260400                                NaN
# Cre01.g025025                                NaN
# Cre02.g077500                                NaN
# Cre07.g330950                                NaN
#
#                 other band - wrong size, too small  schmier ??
# ChlreGene_ID55
# Cre11.g468300                                  NaN         NaN
# Cre06.g260400                                  NaN         NaN
# Cre01.g025025                                  NaN         NaN
# Cre02.g077500                                  NaN         NaN
# Cre07.g330950                                  NaN         NaN

# %%
mask = [True if len(x) != 0 else False for x in df['RNAseq']]
len(df[mask])
# Out:
# 2663

# %%
#mask = (df['# match'] > 1)

# %%
#df['right_size'] = df['genename'].apply(lambda x : df_mayra_i.loc[x]['right size'])
column_in = []
for gn in df['genename']:
    try:
        column_in.append(df_mayra_i.loc[gn]['platename'])
    except KeyError:
        column_in.append(np.nan)
df['platename'] = column_in

column_in = []
for gn in df['genename']:
    try:
        column_in.append(df_mayra_i.loc[gn]['Pos.Nr'])
    except KeyError:
        column_in.append(np.nan)
df['Pos.Nr'] = column_in

column_in = []
for gn in df['genename']:
    try:
        column_in.append(df_mayra_i.loc[gn]['Position'])
    except KeyError:
        column_in.append(np.nan)
df['Position'] = column_in

column_in = []
for gn in df['genename']:
    try:
        column_in.append(df_mayra_i.loc[gn]['right size'])
    except KeyError:
        column_in.append(np.nan)
df['right size'] = column_in

column_in = []
for gn in df['genename']:
    try:
        column_in.append(df_mayra_i.loc[gn]['no band'])
    except KeyError:
        column_in.append(np.nan)
df['no band'] = column_in

column_in = []
for gn in df['genename']:
    try:
        column_in.append(df_mayra_i.loc[gn]['other band - wrong size, too big'])
    except KeyError:
        column_in.append(np.nan)
df['too big'] = column_in

column_in = []
for gn in df['genename']:
    try:
        column_in.append(df_mayra_i.loc[gn]['other band - wrong size, too small'])
    except KeyError:
        column_in.append(np.nan)
df['too small'] = column_in

column_in = []
for gn in df['genename']:
    try:
        column_in.append(df_mayra_i.loc[gn]['schmier ??'])
    except KeyError:
        column_in.append(np.nan)
df['schmier'] = column_in

# %%
df_mayra_i.loc['Cre01.g041583']
# Out:
# Chlre4_ID                             jgi|Chlre4|146735
# right size                                            0
# band - wrong size                                   NaN
# no band                                               1
# platename                                      P2kCre39
# Pos.Nr                                               65
# Position                                             A9
# ORF_Size5                                          1599
# right size.1                                          0
# band - wrong size.1                                 NaN
# no band.1                                             1
# other band - wrong size, too big                    NaN
# other band - wrong size, too small                  NaN
# schmier ??                                          NaN
# Name: Cre01.g041583, dtype: object

# %%
mask = (df['too big'].astype(str) == '1.0')

# %%
mask = (df['offtarget'] == 1)
df[mask]
# Out:
#            genename  offtarget  # match within CDS     CDS     Gene  \
# 44    Cre11.g467717          1                   1   [990]   [3256]
# 155   Cre06.g253851          1                   1   [780]   [1301]
# 274   Cre02.g142687          1                   1   [543]   [1151]
# 290   Cre02.g083350          1                   1   [522]    [661]
# 357   Cre03.g180400          1                   1   [759]    [759]
# 368   Cre01.g016750          1                   1   [735]   [1117]
# 376   Cre01.g025025          1                   1   [390]    [390]
# 385   Cre01.g016600          1                   1   [735]   [1116]
# 467   Cre12.g553300          1                   1   [834]    [834]
# 489   Cre12.g486250          1                   1   [543]   [1152]
# 503   Cre08.g376550          1                   1   [315]    [315]
# 521   Cre08.g367500          1                   1   [777]   [1368]
# 533   Cre07.g330000          1                   1   [249]    [249]
# 560   Cre14.g622600          1                   1   [840]   [1555]
# 643   Cre06.g283950          1                   1   [762]   [1336]
# 647   Cre06.g284250          1                   1   [762]   [1438]
# 687   Cre17.g719100          1                   1   [561]   [1012]
# 690   Cre17.g719537          1                   1   [264]    [359]
# 706   Cre17.g722616          1                   1   [252]    [252]
# 717   Cre05.g243600          1                   1   [408]    [408]
# 719   Cre05.g243650          1                   1   [651]   [1595]
# 727   Cre05.g248450          1                   1   [801]   [1739]
# 797   Cre02.g091300          1                   1   [609]   [1405]
# 921   Cre10.g435200          1                   1   [552]   [1354]
# 998   Cre12.g548400          1                   1   [747]   [1441]
# 1001  Cre12.g548950          1                   1   [747]   [1370]
# 1068  Cre11.g467718          1                   1   [954]   [2492]
# 1126  Cre16.g684550          1                   1   [522]    [832]
# 1299  Cre02.g120100          1                   1   [555]   [1125]
# 1319  Cre02.g120150          1                   1   [555]   [1267]
# ...             ...        ...                 ...     ...      ...
# 2926  Cre10.g433200          1                   1  [1923]   [3052]
# 2993  Cre12.g549550          1                   1  [1329]   [1873]
# 3074  Cre16.g671400          1                   1  [1947]   [4744]
# 3133  Cre06.g266000          1                   1  [1113]   [1640]
# 3214  Cre17.g746697          1                   1  [1512]   [5668]
# 3314  Cre03.g195100          1                   1  [1476]   [1476]
# 3393  Cre01.g059252          1                   1  [1434]   [2463]
# 3442  Cre04.g224300          1                   1  [1053]   [3042]
# 3506  Cre08.g365300          1                   1  [1656]   [1807]
# 3531  Cre07.g343300          1                   1  [3477]   [3620]
# 3545  Cre07.g343567          1                   1  [3186]   [3514]
# 3567  Cre07.g343250          1                   1  [3459]   [3606]
# 3586  Cre11.g476325          1                   1  [2745]  [12422]
# 3643  Cre06.g303100          1                   1  [1866]   [3945]
# 3670  Cre06.g306050          1                   1  [1872]   [3767]
# 3756  Cre15.g637602          1                   1  [2838]   [5361]
# 3773  Cre13.g572272          1                   1  [3261]   [3818]
# 4134  Cre06.g262500          1                   1  [3693]   [3693]
# 4157  Cre06.g262550          1                   1  [3492]   [3492]
# 4217  Cre17.g745347          1                   1  [3690]   [5954]
# 4269  Cre13.g578074          1                   1  [3276]   [4604]
# 4283  Cre13.g578200          1                   1  [3207]   [3678]
# 4451  Cre04.g229374          1                   1  [2562]   [2562]
# 4457  Cre04.g217923          1                   1  [2739]   [3961]
# 4490  Cre12.g542800          1                   1  [3678]  [10992]
# 4508  Cre12.g512100          1                   1  [3840]   [4862]
# 4523  Cre08.g369720          1                   1  [4686]   [7274]
# 4544  Cre07.g322850          1                   1  [4923]   [8302]
# 4571  Cre14.g608300          1                   1  [5010]   [5954]
# 4805  Cre03.g144084          1                   1  [3168]   [3703]
#
#                                                  RNAseq  platename  Pos.Nr  \
# 44                                                [990]   P1kCre11      11
# 155                                                  []    P1kCre7      87
# 274                                [543, 543, 543, 543]    P1kCre5      62
# 290                 [627, 216, 645, 627, 645, 645, 645]    P1kCre5      51
# 357                                               [759]    P1kCre7      79
# 368                                               [735]    P1kCre7      57
# 376                      [390, 408, 390, 408, 408, 408]  P1kCre1+2       3
# 385                                               [735]    P1kCre7      56
# 467                                                  []    P1kCre9      19
# 489                                [543, 543, 543, 543]    P1kCre5      64
# 503                                          [315, 315]   P1kCre17      58
# 521                                                  []   P1kCre15      21
# 533                                               [249]   P1kCre17      50
# 560                                                  []   P1kCre15      58
# 643                                                  []   P1kCre19      85
# 647                                                  []   P1kCre15      14
# 687                                          [561, 549]   P1kCre13      16
# 690                 [359, 359, 359, 338, 359, 359, 332]   P1kCre11      28
# 706       [240, 240, 240, 240, 240, 240, 194, 240, 240]   P1kCre17      52
# 717                                               [402]   P1kCre11      64
# 719                                          [651, 651]   P1kCre13      53
# 727                                               [801]   P1kCre15      39
# 797                                [769, 609, 802, 642]   P1kCre13      36
# 921       [567, 588, 588, 567, 552, 639, 555, 618, 588]   P1kCre19      13
# 998                                          [747, 747]   P1kCre15       8
# 1001                                         [747, 747]   P1kCre15       9
# 1068                                              [954]   P1kCre25      62
# 1126                                    [522, 519, 519]   P1kCre25      26
# 1299                                         [555, 555]   P1kCre25      28
# 1319                                         [555, 555]   P1kCre25      29
# ...                                                 ...        ...     ...
# 2926                                                 []   P2kCre53      44
# 2993                                 [1329, 1329, 1329]   P2kCre57      93
# 3074                                                 []   P2kCre69      34
# 3133                                                 []   P2kCre65      47
# 3214  [381, 402, 381, 402, 381, 402, 418, 123, 381, ...   P2kCre67      47
# 3314                                 [1476, 1476, 1476]   P2kCre67      34
# 3393  [1341, 1395, 1341, 1481, 1427, 1380, 1395, 143...   P2kCre71      66
# 3442                                       [1228, 1053]   P2kCre65      29
# 3506                                             [1656]   P2kCre75       6
# 3531                                                 []        NaN     NaN
# 3545                                                 []   P4kCre83      72
# 3567                                                 []        NaN     NaN
# 3586                                             [2922]   P4kCre83       4
# 3643                                 [1866, 1824, 1866]   P2kCre75      20
# 3670                                 [1866, 1824, 1866]   P2kCre75      21
# 3756                                                 []   P4kCre83      18
# 3773                                                 []   P4kCre83      85
# 4134                                                 []        NaN     NaN
# 4157                                                 []        NaN     NaN
# 4217                                                 []        NaN     NaN
# 4269                                                 []        NaN     NaN
# 4283                                                 []        NaN     NaN
# 4451                                                 []        NaN     NaN
# 4457                                                 []        NaN     NaN
# 4490                                             [3681]        NaN     NaN
# 4508                                             [3840]        NaN     NaN
# 4523                                                 []        NaN     NaN
# 4544                                                 []        NaN     NaN
# 4571                                                 []        NaN     NaN
# 4805                                                 []        NaN     NaN
#
#      Position  right size  no band  too big  too small  schmier
# 44         C2           1      NaN      NaN        NaN      NaN
# 155       G11           0        0        1        NaN      NaN
# 274        F8           1      NaN      NaN        NaN      NaN
# 290        C7           0        1      NaN        NaN      NaN
# 357       G10           0        1      NaN        NaN      NaN
# 368        A8           0        1      NaN        NaN      NaN
# 376        C1           0        1      NaN        NaN      NaN
# 385        H7           1      NaN      NaN        NaN      NaN
# 467        C3           0        1      NaN        NaN      NaN
# 489        H8           1      NaN      NaN        NaN      NaN
# 503        B8           1      NaN      NaN        NaN      NaN
# 521        E3           1      NaN      NaN        NaN      NaN
# 533        B7           1      NaN      NaN        NaN      NaN
# 560        B8           1      NaN      NaN        NaN      NaN
# 643       E11           1      NaN      NaN        NaN      NaN
# 647        F2           1      NaN      NaN        NaN      NaN
# 687        H2           1      NaN      NaN        NaN      NaN
# 690        D4           0        1      NaN        NaN      NaN
# 706        D7           0        0        1        NaN      NaN
# 717        H8           0        1      NaN        NaN      NaN
# 719        E7           1      NaN      NaN        NaN      NaN
# 727        G5           1      NaN      NaN        NaN      NaN
# 797        D5           1      NaN      NaN        NaN      NaN
# 921        E2           1      NaN      NaN        NaN      NaN
# 998        H1           1      NaN      NaN        NaN      NaN
# 1001       A2           1      NaN      NaN        NaN      NaN
# 1068       F8           1      NaN      NaN        NaN      NaN
# 1126       B4           1      NaN      NaN        NaN      NaN
# 1299       D4           1      NaN      NaN        NaN      NaN
# 1319       E4           1      NaN      NaN        NaN      NaN
# ...       ...         ...      ...      ...        ...      ...
# 2926       D6           0        1      NaN        NaN      NaN
# 2993      E12           1      NaN      NaN        NaN      NaN
# 3074       B5           1      NaN      NaN          1      NaN
# 3133       G6           1      NaN      NaN        NaN      NaN
# 3214       G6           0        1      NaN        NaN        1
# 3314       B5           0        1      NaN        NaN        1
# 3393       B9           1      NaN      NaN        NaN      NaN
# 3442       E4           1      NaN      NaN        NaN      NaN
# 3506       F1           0        1      NaN        NaN      NaN
# 3531      NaN         NaN      NaN      NaN        NaN      NaN
# 3545       H9           1      NaN      NaN          1      NaN
# 3567      NaN         NaN      NaN      NaN        NaN      NaN
# 3586       D1           1      NaN      NaN        NaN      NaN
# 3643       D3           1      NaN      NaN          1      NaN
# 3670       E3           1      NaN      NaN          1      NaN
# 3756       B3           0        1      NaN        NaN      NaN
# 3773      E11           1      NaN      NaN        NaN      NaN
# 4134      NaN         NaN      NaN      NaN        NaN      NaN
# 4157      NaN         NaN      NaN      NaN        NaN      NaN
# 4217      NaN         NaN      NaN      NaN        NaN      NaN
# 4269      NaN         NaN      NaN      NaN        NaN      NaN
# 4283      NaN         NaN      NaN      NaN        NaN      NaN
# 4451      NaN         NaN      NaN      NaN        NaN      NaN
# 4457      NaN         NaN      NaN      NaN        NaN      NaN
# 4490      NaN         NaN      NaN      NaN        NaN      NaN
# 4508      NaN         NaN      NaN      NaN        NaN      NaN
# 4523      NaN         NaN      NaN      NaN        NaN      NaN
# 4544      NaN         NaN      NaN      NaN        NaN      NaN
# 4571      NaN         NaN      NaN      NaN        NaN      NaN
# 4805      NaN         NaN      NaN      NaN        NaN      NaN
#
# [98 rows x 14 columns]

# %%
df.to_csv('primer_ePCR.txt')

# %%
df_out.to_csv('primer_ePCR_offtartget.txt')
