# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.backends.backend_pdf import PdfPages
matplotlib.style.use('ggplot') 

import sys
sys.path.append("../")
import kang

# %%
df_cds_crenew_index = pd.read_pickle('../../braker/cre.cds.braker.chlamy20151203.augustus.gff.rmsharp.gff.parsed.gff.p')
df_cds_crenew = df_cds_crenew_index.reset_index()

df_crenew_gene,df_crenew_cds = get_df_gff('../../braker/braker.chlamy20151203.augustus.gff.rmsharp.gff.parsed.gff')

mask = (df_cds_crenew['transcript'] == 't1')
df_cds_crenew_gene = df_cds_crenew[mask]

crenew_genenum      = len(df_cds_crenew_gene)
cds_len_list_crenew = np.array([len(x) for x in df_cds_crenew_gene['CDSseq']])

# %%
file_fa_cds_cre = '../../../Cre/DroughtNet/PhytozomeV10_download/PhytozomeV10/Creinhardtii/annotation/Creinhardtii_281_v5.5.cds_primaryTranscriptOnly.fa'
dicHD2seq_cre = kang.Fasta2dic(file_fa_cds_cre)
cds_len_list_cre = np.array([len(x) for x in dicHD2seq_cre.values()])
cre_genenum = len(dicHD2seq_cre.keys())

file_fa_cds_ath = '../../../Cre/DroughtNet/PhytozomeV10_download/PhytozomeV10/Athaliana/annotation/Athaliana_167_TAIR10.cds_primaryTranscriptOnly.fa'
dicHD2seq_ath = kang.Fasta2dic(file_fa_cds_ath)
cds_len_list_ath = np.array([len(x) for x in dicHD2seq_ath.values()])
ath_genenum = len(dicHD2seq_ath.keys())

# %%
def get_df_gff(file_gff):
    #file_gff_ori = '../../genemodel_correction/Creinhardtii_281_v5.5.gene.gff3'
    df_ori = pd.read_csv(file_gff,sep='\t',header=None,skiprows=2)
    df_ori_gene = df_ori[df_ori[2]=='gene'] 
    df_ori_cds = df_ori[df_ori[2]=='CDS'] 
    df_ori_gene['length'] = df_ori_gene.apply(lambda x : x[4] - x[3],axis=1)
    df_ori_cds['length'] = df_ori_cds.apply(lambda x : x[4] - x[3],axis=1)
    return df_ori_gene, df_ori_cds
df_cre_gene,df_cre_cds = get_df_gff('../../genemodel_correction/Creinhardtii_281_v5.5.gene.gff3')
df_ath_gene,df_ath_cds = get_df_gff('../../DroughtNet/PhytozomeV10_download/PhytozomeV10/Athaliana/annotation/Athaliana_167_TAIR10.gene.gff3')

df_cre_gene['genename'] = df_cre_gene[8].apply(lambda x : x.split(';')[1].replace('Name=',''))
df_cre_gene_index = df_cre_gene.set_index('genename')

# %%
df_cre_gene_index.head()
# Out:
#                           0             1     2      3      4  5  6  7  \
# genename
# Cre01.g000017  chromosome_1  phytozomev10  gene  18766  20237  .  +  .
# Cre01.g000033  chromosome_1  phytozomev10  gene  20356  23957  .  +  .
# Cre01.g000050  chromosome_1  phytozomev10  gene  24026  30617  .  +  .
# Cre01.g000100  chromosome_1  phytozomev10  gene  30776  41037  .  +  .
# Cre01.g000150  chromosome_1  phytozomev10  gene  41896  46547  .  +  .
#
#                                                       8  length
# genename
# Cre01.g000017  ID=Cre01.g000017.v5.5;Name=Cre01.g000017    1471
# Cre01.g000033  ID=Cre01.g000033.v5.5;Name=Cre01.g000033    3601
# Cre01.g000050  ID=Cre01.g000050.v5.5;Name=Cre01.g000050    6591
# Cre01.g000100  ID=Cre01.g000100.v5.5;Name=Cre01.g000100   10261
# Cre01.g000150  ID=Cre01.g000150.v5.5;Name=Cre01.g000150    4651

# %%
# genelist of gene with bam coverage
df_table = pd.read_pickle('../../genemodel_correction/tophat/cre.genemodelcomp.total.addRNAseqpairedendcov.pk')

mask                            = (df_table['Genecov'] > 0.9)
genelist_genecov                = df_table[mask]['genename']
array_genelen_genelist_gene_cov = [df_cre_gene_index.loc[x]['length'] for x in genelist_genecov]
array_cdslen_genelist_gene_cov  =

# %%
def get_two_hist(ax1,ax2,array1,array2,xlim,title):
    a1,b1,c1 = ax1.hist(array1,bins=np.arange(0,max(array1),1),histtype='step',alpha=0.7)
    a2,b2,c2 = ax1.hist(array2,bins=np.arange(0,max(array1),1),histtype='step',alpha=0.7)
    ax1.set_xlim(0,xlim)
    ax1.set_title(title)
    ax1.set_xlabel('Length (bp)')
    ax1.set_ylabel('Count')
    ax2.plot(b1[0:len(a1)],a1/ath_genenum,alpha=0.8)
    ax2.plot(b2[0:len(a2)],a2/cre_genenum,alpha=0.8)
    ax2.set_xlim(0,xlim)
    ax2.set_title(title)
    ax2.set_xlabel('Length (bp)')
    ax2.set_ylabel('Ratio (Count/total # genes)')
    if title == 'Gene':
        ax1.set_ylim(0,35)
        ax2.set_ylim(0,0.0014)

# %%
fig, (ax1,ax2,ax3,ax4) = plt.subplots(4,3,figsize=(15, 25))

# %%
fig, (ax1,ax2,ax3,ax4) = plt.subplots(4,3,figsize=(15, 25))

get_two_hist(ax1[0],ax2[0],df_ath_cds['length'],df_cre_cds['length'],1000,'Exon')
get_two_hist(ax3[0],ax4[0],df_ath_cds['length'],df_crenew_cds['length'],1000,'Exon')

get_two_hist(ax1[1],ax2[1],cds_len_list_ath,cds_len_list_cre,20000,'Codingsequence')
get_two_hist(ax3[1],ax4[1],cds_len_list_ath,cds_len_list_crenew,20000,'Codingsequence')

get_two_hist(ax1[2],ax2[2],df_ath_gene['length'],df_cre_gene['length'],50000,'Gene')
get_two_hist(ax3[2],ax4[2],df_ath_gene['length'],df_crenew_gene['length'],50000,'Gene')

plt.tight_layout()

# %%
fig, (ax,ax2,ax3,ax4) = plt.subplots(4,3,figsize=(15, 20))
#fig1, ax2 = plt.subplots(1,3,figsize=(15, 5))

#a,b,c = ax.hist(j,bins=x,color=colors[i],label=labels[i])
#ax2.plot(b[0:len(a)],a,alpha=0.9,color=colors[i],label=labels[i])
#ax[0].hist(df_ath_cds['length'],histtype='stepfilled')
a1,b1,c1 = ax[0].hist(df_ath_cds['length'],bins=np.arange(0,max(df_ath_cds['length']),1),histtype='step',alpha=0.7)
a2,b2,c2 = ax[0].hist(df_cre_cds['length'],bins=np.arange(0,max(df_ath_cds['length']),1),histtype='step',alpha=0.7)
ax[0].set_xlim(0,1000)
ax[0].set_title('Exon')
ax[0].set_xlabel('Length (bp)')
ax[0].set_ylabel('Count')
ax2[0].plot(b1[0:len(a1)],a1/ath_genenum,alpha=0.8)
ax2[0].plot(b2[0:len(a2)],a2/cre_genenum,alpha=0.8)
ax2[0].set_xlim(0,1000)
ax2[0].set_title('Exon')
ax2[0].set_xlabel('Length (bp)')
ax2[0].set_ylabel('Ratio (Count/total # genes)')



a1,b1,c1 = ax[2].hist(df_ath_gene['length'],bins=np.arange(0,max(df_ath_gene['length']),1),label='A.thaliana',histtype='step',alpha=0.7)
a2,b2,c2 = ax[2].hist(df_cre_gene['length'],bins=np.arange(0,max(df_ath_gene['length']),1),label='C.reinhardtii',histtype='step',alpha=0.7)
handles, labels = ax[2].get_legend_handles_labels()
ax[2].legend(handles, labels)
ax[2].set_title('Gene')
ax[2].set_xlabel('Length (bp)')
ax[2].set_ylabel('Count')

ax2[2].plot(b1[0:len(a1)],a1/ath_genenum,alpha=0.8)
ax2[2].plot(b2[0:len(a2)],a2/cre_genenum,alpha=0.8)
ax2[2].set_title('Gene')
ax2[2].set_xlabel('Length (bp)')
ax2[2].set_ylabel('Ratio (Count/total # genes)')


a1,b1,c1 = ax[1].hist(cds_len_list_ath,bins=np.arange(0,max(cds_len_list_cre),1),label='A.thaliana',histtype='step',alpha=0.7)
a2,b2,c2 = ax[1].hist(cds_len_list_cre,bins=np.arange(0,max(cds_len_list_cre),1),label='C.reinhardtii',histtype='step',alpha=0.7)
handles, labels = ax[1].get_legend_handles_labels()

ax[1].set_title('Coding sequence')
ax[1].set_xlabel('Length (bp)')
ax[1].set_ylabel('Count')
ax[1].set_xlim(0,20000)

ax2[1].plot(b1[0:len(a1)],a1/ath_genenum,alpha=0.8)
ax2[1].plot(b2[0:len(a2)],a2/cre_genenum,alpha=0.8)
ax2[1].set_title('Coding sequence')
ax2[1].set_xlabel('Length (bp)')
ax2[1].set_ylabel('Ratio (Count/total # genes)')
ax2[1].set_xlim(0,20000)
plt.tight_layout()

# %%
pp = PdfPages('cre.lengthcomp.exonvsgene.pdf')
plt.savefig(pp, format='pdf')
pp.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-b251014a5860> in <module>()
# ----> 1 fig, (ax,ax2) = plt.subplots(4,3,figsize=(15, 20))
#       2 #fig1, ax2 = plt.subplots(1,3,figsize=(15, 5))
#       3
#       4 #a,b,c = ax.hist(j,bins=x,color=colors[i],label=labels[i])
#       5 #ax2.plot(b[0:len(a)],a,alpha=0.9,color=colors[i],label=labels[i])
#
# ValueError: too many values to unpack

# %%
max(cds_len_list_cre)
# Out:
# 71580

# %%
max(df_cre_gene['length'])
# Out:
# 108751
